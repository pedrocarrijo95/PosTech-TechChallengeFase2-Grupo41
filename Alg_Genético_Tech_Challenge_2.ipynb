# %% [markdown]
# # A Nuvem Inteligente
# Em uma empresa de tecnologia, a equipe técnica enfrentava um grande desafio: alocar eficientemente recursos de CPU e memória nos servidores da nuvem para atender às demandas dos clientes. A solução manual estava se tornando impraticável e cara.
#
# # O Desafio
# A equipe precisava encontrar uma maneira de minimizar os custos operacionais e garantir tempos de resposta rápidos, ajustando dinamicamente a alocação de recursos em um ambiente de nuvem.
#
# # A Solução Genética
# Eles decidiram usar um algoritmo genético para resolver o problema. Este algoritmo funciona imitando a evolução natural:
#
# **Inicialização:** Começa com várias configurações aleatórias de recursos dos servidores.
#
# **Avaliação:** Calcula o desempenho de cada configuração, considerando tempo de resposta e custo.
#
# **Seleção:** Escolhe as melhores configurações.
#
# **Cruzamento e Mutação:** Combina e modifica ligeiramente essas configurações para criar novas.
#
# **Iteração:** Repete o processo várias vezes, melhorando a cada geração.
#
# **O Resultado**
# Após várias iterações, o algoritmo encontrou configurações ótimas que usavam os recursos de maneira eficiente, reduzindo custos e melhorando os tempos de resposta. A nuvem agora ajustava-se automaticamente às demandas dos clientes.
#
# # Conclusão
# Com o algoritmo genético, a equipe técnica conseguiu otimizar a alocação de recursos na nuvem, tornando o sistema mais eficiente e econômico.

# %%
import random
import math
import copy
from typing import List, Tuple

min_cpu_capacity = 1 #Min de CPU configurável
max_cpu_capacity = 100 #Max de CPU configurável
min_memory_capacity = 8 #Min de RAM configurável
max_memory_capacity = 1000 #Max de RAM configurável

fixed_cost = 50.0 #Custo Fixo
cpu_cost = 0.5 #Custo fixo de CPU
memory_cost = 0.2 #Custo fixo de RAM

#Gerar demandas de clientes de forma aleatórias
def generate_client_demands(num_clients: int) -> List[Tuple[int, int]]:
    client_demands = []
    for _ in range(num_clients):
        cpu_demand = random.randint(1, 90)  # Demanda de CPU (unidades)
        memory_demand = random.randint(1, 700)  # Demanda de memória (GB)
        client_demands.append((cpu_demand, memory_demand))
    return client_demands

#Gerar populacão de "servidores" de forma aleatória (cpu,ram)
def generate_initial_population(population_size: int, min_cpu_capacity: int, max_cpu_capacity: int, min_memory_capacity: int, max_memory_capacity: int) -> List[Tuple[int, int]]:
    population = []
    for _ in range(population_size):
        cpu_capacity = random.randint(min_cpu_capacity, max_cpu_capacity)
        memory_capacity = random.randint(min_memory_capacity, max_memory_capacity)
        population.append((cpu_capacity, memory_capacity))
    return population


#Calculo do tempo de resposta
def calculate_response_time(cpu_demand: int, memory_demand: int, server_capacity: Tuple[int, int]) -> float:
    #Calcula a porcentagem de utilizacão da CPU
    cpu_utilization = cpu_demand / server_capacity[0]
    #Calcula a porcentagem de utilizacão da RAM
    memory_utilization = memory_demand / server_capacity[1]
    #Coleta o maior valor entre as 2 utilizacões
    utilization = max(cpu_utilization, memory_utilization)
    base_time = 10  # Tempo base para processamento (ms)

    #Calcula o tempo de resposta baseado na utilizacão maior.
    response_time = base_time / (1 - utilization) if utilization < 1 else float('inf')

    return response_time

#Calculo do custo se baseando na configuracão do servidor passado e os custos fixos
def calculate_operational_cost(server_capacity: Tuple[int, int], fixed_cost: float, cpu_cost: float, memory_cost: float) -> float:
    return fixed_cost + (server_capacity[0] * cpu_cost) + (server_capacity[1] * memory_cost)

#Cálculo do fitness (A soma do tempo de resposta + custo operacional, sendo 70% para tempo de resposta e 30% para custo os pesos)
def calculate_fitness(server_capacity: Tuple[int, int], client_demands: List[Tuple[int, int]], fixed_cost: float, cpu_cost: float, memory_cost: float) -> float:
    total_response_time = 0
    #Loop para passar as demandas dos clientes que foram geradas
    for cpu_demand, memory_demand in client_demands:
        #Calculo do tempo de resposta do servidor atual baseado nas demandas dos clientes
        total_response_time += calculate_response_time(cpu_demand, memory_demand, server_capacity)
    #média final
    average_response_time = total_response_time / len(client_demands)
    #custo operacional baseado no servidor atual (individuo)
    operational_cost = calculate_operational_cost(server_capacity, fixed_cost, cpu_cost, memory_cost)

    # Peso de 70% para o tempo de resposta e 30% para o custo operacional
    weighted_fitness = 0.7 * average_response_time + 0.3 * operational_cost

    return weighted_fitness

#Cruzamento
def crossover(parent1: Tuple[int, int], parent2: Tuple[int, int]) -> Tuple[int, int]:
    #Sorteia aleatoriamente número de 0 a 1
    crossover_point = random.randint(0, 1)
    if crossover_point == 0:
        #Se caso for zero é invertido a posicão 0 pega do parent1 e a posicão 1 do parent2 (cpu,ram)
        return (parent1[0], parent2[1])
    else:
        #Ao contrário pega a posicão 0 do parent2 e a posicão 1 do parent1 (cpu,ram)
        return (parent2[0], parent1[1])

#Mutacão
def mutate(individual: Tuple[int, int], mutation_probability: float, min_cpu_capacity: int, max_cpu_capacity: int, min_memory_capacity: int, max_memory_capacity: int) -> Tuple[int, int]:
    r = random.random()
    #Se caso número aleatório for abaixo da taxa de mutacão
    if r < mutation_probability:
        #é gerado novamente de forma aleatória novas CPU e RAM para o servidor filho (child)
        new_cpu_capacity = random.randint(min_cpu_capacity, max_cpu_capacity)
        new_memory_capacity = random.randint(min_memory_capacity, max_memory_capacity)
        return (new_cpu_capacity, new_memory_capacity)
    else:
        #Ao contrário simplesmente retorna o individuo como ele realmente é e somente com o cruzamento feito.
        return individual


def sort_population(population: List[List[Tuple[float, float]]], fitness: List[float]) -> Tuple[List[List[Tuple[float, float]]], List[float]]:

    combined_lists = list(zip(population, fitness))

    #Organiza a populacão de individuos com base na ordem crescente do fitness
    sorted_combined_lists = sorted(combined_lists, key=lambda x: x[1])

    #Separa as listas novamente em population e fitness
    sorted_population, sorted_fitness = zip(*sorted_combined_lists)

    return sorted_population, sorted_fitness


if __name__ == '__main__':

    POPULATION_SIZE = 100
    N_GENERATIONS = 500
    MUTATION_PROBABILITY = 0.8

    # Cria a populacão inicial de servidores de forma aleatória
    population = generate_initial_population(population_size=POPULATION_SIZE,min_cpu_capacity=min_cpu_capacity,max_cpu_capacity=max_cpu_capacity,min_memory_capacity=min_memory_capacity,max_memory_capacity=max_memory_capacity)

    # Variaveis para guardar os melhores resultados
    melhor_fitness_values = []
    melhores_solucoes = []
    melhores_solucoes.append((0,0))

    # Gerar demandas dos clientes
    client_demands = generate_client_demands(100)
    print(f"Client Demands {client_demands}")
    print(f"Server Capacities {population}")

    #Para cada geracão
    for generation in range(N_GENERATIONS):

        #É feito o cálculo do fitness de cada individuo, passando por cada um dos servidores gerados aleatoriamente no inicio do algoritmo.
        population_fitness = [calculate_fitness(individual,client_demands, fixed_cost, cpu_cost, memory_cost) for individual in population]

        #Organiza em forma crescente baseado no fitness
        population, population_fitness = sort_population(population,  population_fitness)


        #Salva o melhor fitness e a melhor solucão, calcula o fitness baseado na posicão [0] da population que em ordem crescente seria a menor.
        melhor_fitness = calculate_fitness(population[0],client_demands, fixed_cost, cpu_cost, memory_cost)
        melhor_solucao = population[0]

        #Verificamos aqui se a melhor_solucao atual é diferente da última melhor solucão que salvamos em melhores_solucoes[]
        if melhor_solucao != melhores_solucoes[-1]:
          #Se sim, printamos que existe uma nova melhor solucão e qual é o seu fitness e com separadores para serem destacados no nosso console.
          print(f"\n//////\nNova Melhor: {melhor_solucao}")
          print(f"Geracão {generation}: Melhor fitness = {melhor_fitness} Melhor solucão = {melhor_solucao}\n//////\n")
        else:
            #Ao contrário somente repetimos a mesma solucão enquanto não acharmos uma melhor
            print(f"Geracão {generation}: Melhor solucão = {melhor_solucao}")

        #No fim atualizamos nossa lista das melhores solucões e adicionamos nosso último melhor fitness e última melhor solucão.
        melhor_fitness_values.append(melhor_fitness)
        melhores_solucoes.append(melhor_solucao)

        #Iniciamos uma populacão do zero mantendo somente o melhor indivíduo da última
        new_population = [population[0]]

        while len(new_population) < POPULATION_SIZE:

            # Selecão
            parent1, parent2 = random.choices(population[:10], k=2)  # Seleciona aleatoriamente dois indivíduos anteriores do top 10.

            # Cruzamento
            child1 = crossover(parent1, parent2) #Realiza o cruzamento desses indivíduos

            # Mutacão
            child1 = mutate(child1, MUTATION_PROBABILITY,min_cpu_capacity,max_cpu_capacity,min_memory_capacity,max_memory_capacity) #Testa a probabilidade de mutacão e coleta o resultado final.

            #Adiciona na nova populacão a nova crianca
            new_population.append(child1)

        #Seta a nova populacão após finalizar o loop para iniciar tudo novamente.
        population = new_population
# Out:
# Client Demands [(66, 632), (71, 496), (73, 325), (89, 666), (89, 558), (53, 593), (23, 611), (45, 183), (10, 371), (13, 499), (4, 143), (33, 443), (74, 147), (86, 158), (64, 433), (29, 229), (19, 295), (70, 113), (7, 480), (67, 576), (53, 674), (89, 659), (86, 241), (2, 353), (30, 483), (86, 625), (22, 447), (27, 375), (43, 238), (60, 425), (85, 162), (48, 320), (80, 178), (67, 567), (22, 477), (52, 507), (27, 337), (32, 384), (50, 402), (26, 683), (83, 140), (38, 96), (75, 186), (52, 151), (72, 351), (33, 645), (35, 294), (29, 43), (37, 162), (17, 527), (74, 301), (46, 349), (41, 609), (43, 203), (56, 286), (59, 287), (29, 647), (14, 94), (23, 440), (74, 670), (25, 151), (23, 230), (85, 293), (55, 80), (40, 671), (79, 253), (16, 495), (9, 330), (52, 486), (73, 367), (84, 218), (67, 355), (24, 112), (60, 271), (60, 498), (66, 219), (64, 356), (38, 480), (77, 96), (30, 672), (30, 676), (70, 572), (38, 143), (82, 185), (80, 51), (23, 175), (43, 449), (6, 519), (40, 414), (40, 608), (73, 305), (47, 64), (42, 648), (17, 52), (17, 346), (63, 61), (1, 372), (59, 224), (68, 559), (51, 677)]
# Server Capacities [(14, 307), (51, 783), (20, 645), (33, 866), (97, 880), (14, 687), (93, 608), (91, 740), (87, 295), (25, 527), (52, 691), (71, 853), (38, 293), (66, 532), (17, 348), (60, 198), (12, 99), (10, 329), (72, 592), (35, 114), (30, 856), (87, 692), (98, 880), (12, 11), (50, 273), (34, 956), (72, 399), (11, 718), (44, 84), (54, 788), (31, 758), (3, 524), (79, 970), (37, 801), (65, 623), (34, 776), (47, 893), (94, 950), (94, 739), (4, 101), (97, 314), (17, 36), (36, 978), (11, 965), (48, 761), (21, 869), (15, 508), (45, 117), (59, 491), (95, 520), (48, 251), (76, 574), (69, 644), (25, 440), (8, 813), (6, 752), (5, 660), (46, 171), (5, 220), (100, 595), (58, 934), (74, 441), (36, 85), (23, 97), (26, 771), (79, 621), (25, 886), (20, 111), (69, 927), (82, 384), (10, 831), (75, 91), (65, 314), (12, 501), (84, 380), (81, 850), (73, 801), (36, 843), (17, 223), (38, 672), (32, 414), (19, 523), (51, 17), (79, 753), (38, 681), (45, 990), (97, 926), (32, 60), (95, 165), (89, 183), (98, 817), (46, 699), (77, 511), (21, 644), (87, 493), (75, 193), (30, 255), (44, 91), (59, 635), (49, 493)]
#
# //////
# Nova Melhor: (98, 817)
# Geracão 0: Melhor fitness = 103.46312403873446 Melhor solucão = (98, 817)
# //////
#
# Geracão 1: Melhor solucão = (98, 817)
# Geracão 2: Melhor solucão = (98, 817)
#
# //////
# Nova Melhor: (98, 754)
# Geracão 3: Melhor fitness = 103.14023438982724 Melhor solucão = (98, 754)
# //////
#
#
# //////
# Nova Melhor: (98, 776)
# Geracão 4: Melhor fitness = 102.84963048625676 Melhor solucão = (98, 776)
# //////
#
# Geracão 5: Melhor solucão = (98, 776)
# Geracão 6: Melhor solucão = (98, 776)
# Geracão 7: Melhor solucão = (98, 776)
# Geracão 8: Melhor solucão = (98, 776)
# Geracão 9: Melhor solucão = (98, 776)
# Geracão 10: Melhor solucão = (98, 776)
# Geracão 11: Melhor solucão = (98, 776)
# Geracão 12: Melhor solucão = (98, 776)
# Geracão 13: Melhor solucão = (98, 776)
# Geracão 14: Melhor solucão = (98, 776)
# Geracão 15: Melhor solucão = (98, 776)
# Geracão 16: Melhor solucão = (98, 776)
# Geracão 17: Melhor solucão = (98, 776)
# Geracão 18: Melhor solucão = (98, 776)
# Geracão 19: Melhor solucão = (98, 776)
# Geracão 20: Melhor solucão = (98, 776)
# Geracão 21: Melhor solucão = (98, 776)
# Geracão 22: Melhor solucão = (98, 776)
# Geracão 23: Melhor solucão = (98, 776)
# Geracão 24: Melhor solucão = (98, 776)
# Geracão 25: Melhor solucão = (98, 776)
# Geracão 26: Melhor solucão = (98, 776)
# Geracão 27: Melhor solucão = (98, 776)
# Geracão 28: Melhor solucão = (98, 776)
# Geracão 29: Melhor solucão = (98, 776)
# Geracão 30: Melhor solucão = (98, 776)
# Geracão 31: Melhor solucão = (98, 776)
# Geracão 32: Melhor solucão = (98, 776)
# Geracão 33: Melhor solucão = (98, 776)
# Geracão 34: Melhor solucão = (98, 776)
# Geracão 35: Melhor solucão = (98, 776)
# Geracão 36: Melhor solucão = (98, 776)
# Geracão 37: Melhor solucão = (98, 776)
# Geracão 38: Melhor solucão = (98, 776)
# Geracão 39: Melhor solucão = (98, 776)
# Geracão 40: Melhor solucão = (98, 776)
# Geracão 41: Melhor solucão = (98, 776)
# Geracão 42: Melhor solucão = (98, 776)
# Geracão 43: Melhor solucão = (98, 776)
# Geracão 44: Melhor solucão = (98, 776)
# Geracão 45: Melhor solucão = (98, 776)
# Geracão 46: Melhor solucão = (98, 776)
# Geracão 47: Melhor solucão = (98, 776)
# Geracão 48: Melhor solucão = (98, 776)
# Geracão 49: Melhor solucão = (98, 776)
# Geracão 50: Melhor solucão = (98, 776)
# Geracão 51: Melhor solucão = (98, 776)
# Geracão 52: Melhor solucão = (98, 776)
# Geracão 53: Melhor solucão = (98, 776)
# Geracão 54: Melhor solucão = (98, 776)
# Geracão 55: Melhor solucão = (98, 776)
# Geracão 56: Melhor solucão = (98, 776)
# Geracão 57: Melhor solucão = (98, 776)
# Geracão 58: Melhor solucão = (98, 776)
# Geracão 59: Melhor solucão = (98, 776)
# Geracão 60: Melhor solucão = (98, 776)
# Geracão 61: Melhor solucão = (98, 776)
# Geracão 62: Melhor solucão = (98, 776)
# Geracão 63: Melhor solucão = (98, 776)
# Geracão 64: Melhor solucão = (98, 776)
# Geracão 65: Melhor solucão = (98, 776)
# Geracão 66: Melhor solucão = (98, 776)
# Geracão 67: Melhor solucão = (98, 776)
# Geracão 68: Melhor solucão = (98, 776)
# Geracão 69: Melhor solucão = (98, 776)
# Geracão 70: Melhor solucão = (98, 776)
# Geracão 71: Melhor solucão = (98, 776)
# Geracão 72: Melhor solucão = (98, 776)
# Geracão 73: Melhor solucão = (98, 776)
# Geracão 74: Melhor solucão = (98, 776)
# Geracão 75: Melhor solucão = (98, 776)
# Geracão 76: Melhor solucão = (98, 776)
# Geracão 77: Melhor solucão = (98, 776)
# Geracão 78: Melhor solucão = (98, 776)
#
# //////
# Nova Melhor: (99, 784)
# Geracão 79: Melhor fitness = 102.38800196069305 Melhor solucão = (99, 784)
# //////
#
# Geracão 80: Melhor solucão = (99, 784)
#
# //////
# Nova Melhor: (99, 776)
# Geracão 81: Melhor fitness = 102.36071555397758 Melhor solucão = (99, 776)
# //////
#
# Geracão 82: Melhor solucão = (99, 776)
# Geracão 83: Melhor solucão = (99, 776)
# Geracão 84: Melhor solucão = (99, 776)
# Geracão 85: Melhor solucão = (99, 776)
# Geracão 86: Melhor solucão = (99, 776)
# Geracão 87: Melhor solucão = (99, 776)
# Geracão 88: Melhor solucão = (99, 776)
# Geracão 89: Melhor solucão = (99, 776)
# Geracão 90: Melhor solucão = (99, 776)
# Geracão 91: Melhor solucão = (99, 776)
# Geracão 92: Melhor solucão = (99, 776)
# Geracão 93: Melhor solucão = (99, 776)
# Geracão 94: Melhor solucão = (99, 776)
# Geracão 95: Melhor solucão = (99, 776)
# Geracão 96: Melhor solucão = (99, 776)
# Geracão 97: Melhor solucão = (99, 776)
# Geracão 98: Melhor solucão = (99, 776)
# Geracão 99: Melhor solucão = (99, 776)
# Geracão 100: Melhor solucão = (99, 776)
# Geracão 101: Melhor solucão = (99, 776)
# Geracão 102: Melhor solucão = (99, 776)
# Geracão 103: Melhor solucão = (99, 776)
#
# //////
# Nova Melhor: (100, 783)
# Geracão 104: Melhor fitness = 101.97764213267028 Melhor solucão = (100, 783)
# //////
#
# Geracão 105: Melhor solucão = (100, 783)
#
# //////
# Nova Melhor: (100, 776)
# Geracão 106: Melhor fitness = 101.95681590845359 Melhor solucão = (100, 776)
# //////
#
# Geracão 107: Melhor solucão = (100, 776)
# Geracão 108: Melhor solucão = (100, 776)
# Geracão 109: Melhor solucão = (100, 776)
# Geracão 110: Melhor solucão = (100, 776)
# Geracão 111: Melhor solucão = (100, 776)
# Geracão 112: Melhor solucão = (100, 776)
# Geracão 113: Melhor solucão = (100, 776)
# Geracão 114: Melhor solucão = (100, 776)
# Geracão 115: Melhor solucão = (100, 776)
# Geracão 116: Melhor solucão = (100, 776)
# Geracão 117: Melhor solucão = (100, 776)
# Geracão 118: Melhor solucão = (100, 776)
# Geracão 119: Melhor solucão = (100, 776)
# Geracão 120: Melhor solucão = (100, 776)
# Geracão 121: Melhor solucão = (100, 776)
# Geracão 122: Melhor solucão = (100, 776)
# Geracão 123: Melhor solucão = (100, 776)
# Geracão 124: Melhor solucão = (100, 776)
# Geracão 125: Melhor solucão = (100, 776)
# Geracão 126: Melhor solucão = (100, 776)
# Geracão 127: Melhor solucão = (100, 776)
# Geracão 128: Melhor solucão = (100, 776)
# Geracão 129: Melhor solucão = (100, 776)
# Geracão 130: Melhor solucão = (100, 776)
# Geracão 131: Melhor solucão = (100, 776)
# Geracão 132: Melhor solucão = (100, 776)
# Geracão 133: Melhor solucão = (100, 776)
# Geracão 134: Melhor solucão = (100, 776)
# Geracão 135: Melhor solucão = (100, 776)
# Geracão 136: Melhor solucão = (100, 776)
# Geracão 137: Melhor solucão = (100, 776)
# Geracão 138: Melhor solucão = (100, 776)
# Geracão 139: Melhor solucão = (100, 776)
# Geracão 140: Melhor solucão = (100, 776)
# Geracão 141: Melhor solucão = (100, 776)
# Geracão 142: Melhor solucão = (100, 776)
# Geracão 143: Melhor solucão = (100, 776)
# Geracão 144: Melhor solucão = (100, 776)
# Geracão 145: Melhor solucão = (100, 776)
# Geracão 146: Melhor solucão = (100, 776)
# Geracão 147: Melhor solucão = (100, 776)
# Geracão 148: Melhor solucão = (100, 776)
# Geracão 149: Melhor solucão = (100, 776)
# Geracão 150: Melhor solucão = (100, 776)
# Geracão 151: Melhor solucão = (100, 776)
# Geracão 152: Melhor solucão = (100, 776)
# Geracão 153: Melhor solucão = (100, 776)
# Geracão 154: Melhor solucão = (100, 776)
# Geracão 155: Melhor solucão = (100, 776)
# Geracão 156: Melhor solucão = (100, 776)
# Geracão 157: Melhor solucão = (100, 776)
# Geracão 158: Melhor solucão = (100, 776)
# Geracão 159: Melhor solucão = (100, 776)
# Geracão 160: Melhor solucão = (100, 776)
# Geracão 161: Melhor solucão = (100, 776)
# Geracão 162: Melhor solucão = (100, 776)
# Geracão 163: Melhor solucão = (100, 776)
# Geracão 164: Melhor solucão = (100, 776)
# Geracão 165: Melhor solucão = (100, 776)
# Geracão 166: Melhor solucão = (100, 776)
# Geracão 167: Melhor solucão = (100, 776)
# Geracão 168: Melhor solucão = (100, 776)
# Geracão 169: Melhor solucão = (100, 776)
# Geracão 170: Melhor solucão = (100, 776)
# Geracão 171: Melhor solucão = (100, 776)
# Geracão 172: Melhor solucão = (100, 776)
# Geracão 173: Melhor solucão = (100, 776)
# Geracão 174: Melhor solucão = (100, 776)
# Geracão 175: Melhor solucão = (100, 776)
# Geracão 176: Melhor solucão = (100, 776)
# Geracão 177: Melhor solucão = (100, 776)
# Geracão 178: Melhor solucão = (100, 776)
# Geracão 179: Melhor solucão = (100, 776)
# Geracão 180: Melhor solucão = (100, 776)
# Geracão 181: Melhor solucão = (100, 776)
# Geracão 182: Melhor solucão = (100, 776)
# Geracão 183: Melhor solucão = (100, 776)
# Geracão 184: Melhor solucão = (100, 776)
# Geracão 185: Melhor solucão = (100, 776)
# Geracão 186: Melhor solucão = (100, 776)
# Geracão 187: Melhor solucão = (100, 776)
# Geracão 188: Melhor solucão = (100, 776)
# Geracão 189: Melhor solucão = (100, 776)
# Geracão 190: Melhor solucão = (100, 776)
# Geracão 191: Melhor solucão = (100, 776)
# Geracão 192: Melhor solucão = (100, 776)
# Geracão 193: Melhor solucão = (100, 776)
# Geracão 194: Melhor solucão = (100, 776)
# Geracão 195: Melhor solucão = (100, 776)
# Geracão 196: Melhor solucão = (100, 776)
# Geracão 197: Melhor solucão = (100, 776)
# Geracão 198: Melhor solucão = (100, 776)
# Geracão 199: Melhor solucão = (100, 776)
# Geracão 200: Melhor solucão = (100, 776)
# Geracão 201: Melhor solucão = (100, 776)
# Geracão 202: Melhor solucão = (100, 776)
# Geracão 203: Melhor solucão = (100, 776)
# Geracão 204: Melhor solucão = (100, 776)
# Geracão 205: Melhor solucão = (100, 776)
# Geracão 206: Melhor solucão = (100, 776)
# Geracão 207: Melhor solucão = (100, 776)
# Geracão 208: Melhor solucão = (100, 776)
# Geracão 209: Melhor solucão = (100, 776)
# Geracão 210: Melhor solucão = (100, 776)
# Geracão 211: Melhor solucão = (100, 776)
# Geracão 212: Melhor solucão = (100, 776)
# Geracão 213: Melhor solucão = (100, 776)
# Geracão 214: Melhor solucão = (100, 776)
# Geracão 215: Melhor solucão = (100, 776)
# Geracão 216: Melhor solucão = (100, 776)
# Geracão 217: Melhor solucão = (100, 776)
# Geracão 218: Melhor solucão = (100, 776)
# Geracão 219: Melhor solucão = (100, 776)
# Geracão 220: Melhor solucão = (100, 776)
# Geracão 221: Melhor solucão = (100, 776)
# Geracão 222: Melhor solucão = (100, 776)
# Geracão 223: Melhor solucão = (100, 776)
# Geracão 224: Melhor solucão = (100, 776)
# Geracão 225: Melhor solucão = (100, 776)
# Geracão 226: Melhor solucão = (100, 776)
# Geracão 227: Melhor solucão = (100, 776)
# Geracão 228: Melhor solucão = (100, 776)
# Geracão 229: Melhor solucão = (100, 776)
# Geracão 230: Melhor solucão = (100, 776)
# Geracão 231: Melhor solucão = (100, 776)
# Geracão 232: Melhor solucão = (100, 776)
# Geracão 233: Melhor solucão = (100, 776)
# Geracão 234: Melhor solucão = (100, 776)
# Geracão 235: Melhor solucão = (100, 776)
# Geracão 236: Melhor solucão = (100, 776)
# Geracão 237: Melhor solucão = (100, 776)
# Geracão 238: Melhor solucão = (100, 776)
# Geracão 239: Melhor solucão = (100, 776)
# Geracão 240: Melhor solucão = (100, 776)
# Geracão 241: Melhor solucão = (100, 776)
# Geracão 242: Melhor solucão = (100, 776)
# Geracão 243: Melhor solucão = (100, 776)
# Geracão 244: Melhor solucão = (100, 776)
# Geracão 245: Melhor solucão = (100, 776)
# Geracão 246: Melhor solucão = (100, 776)
# Geracão 247: Melhor solucão = (100, 776)
# Geracão 248: Melhor solucão = (100, 776)
# Geracão 249: Melhor solucão = (100, 776)
# Geracão 250: Melhor solucão = (100, 776)
# Geracão 251: Melhor solucão = (100, 776)
# Geracão 252: Melhor solucão = (100, 776)
# Geracão 253: Melhor solucão = (100, 776)
# Geracão 254: Melhor solucão = (100, 776)
# Geracão 255: Melhor solucão = (100, 776)
# Geracão 256: Melhor solucão = (100, 776)
# Geracão 257: Melhor solucão = (100, 776)
# Geracão 258: Melhor solucão = (100, 776)
# Geracão 259: Melhor solucão = (100, 776)
# Geracão 260: Melhor solucão = (100, 776)
# Geracão 261: Melhor solucão = (100, 776)
# Geracão 262: Melhor solucão = (100, 776)
# Geracão 263: Melhor solucão = (100, 776)
# Geracão 264: Melhor solucão = (100, 776)
# Geracão 265: Melhor solucão = (100, 776)
# Geracão 266: Melhor solucão = (100, 776)
# Geracão 267: Melhor solucão = (100, 776)
# Geracão 268: Melhor solucão = (100, 776)
# Geracão 269: Melhor solucão = (100, 776)
# Geracão 270: Melhor solucão = (100, 776)
# Geracão 271: Melhor solucão = (100, 776)
# Geracão 272: Melhor solucão = (100, 776)
# Geracão 273: Melhor solucão = (100, 776)
# Geracão 274: Melhor solucão = (100, 776)
# Geracão 275: Melhor solucão = (100, 776)
# Geracão 276: Melhor solucão = (100, 776)
# Geracão 277: Melhor solucão = (100, 776)
# Geracão 278: Melhor solucão = (100, 776)
# Geracão 279: Melhor solucão = (100, 776)
# Geracão 280: Melhor solucão = (100, 776)
# Geracão 281: Melhor solucão = (100, 776)
# Geracão 282: Melhor solucão = (100, 776)
# Geracão 283: Melhor solucão = (100, 776)
# Geracão 284: Melhor solucão = (100, 776)
# Geracão 285: Melhor solucão = (100, 776)
# Geracão 286: Melhor solucão = (100, 776)
# Geracão 287: Melhor solucão = (100, 776)
# Geracão 288: Melhor solucão = (100, 776)
# Geracão 289: Melhor solucão = (100, 776)
# Geracão 290: Melhor solucão = (100, 776)
# Geracão 291: Melhor solucão = (100, 776)
# Geracão 292: Melhor solucão = (100, 776)
# Geracão 293: Melhor solucão = (100, 776)
# Geracão 294: Melhor solucão = (100, 776)
# Geracão 295: Melhor solucão = (100, 776)
# Geracão 296: Melhor solucão = (100, 776)
# Geracão 297: Melhor solucão = (100, 776)
# Geracão 298: Melhor solucão = (100, 776)
# Geracão 299: Melhor solucão = (100, 776)
# Geracão 300: Melhor solucão = (100, 776)
# Geracão 301: Melhor solucão = (100, 776)
# Geracão 302: Melhor solucão = (100, 776)
# Geracão 303: Melhor solucão = (100, 776)
# Geracão 304: Melhor solucão = (100, 776)
# Geracão 305: Melhor solucão = (100, 776)
# Geracão 306: Melhor solucão = (100, 776)
# Geracão 307: Melhor solucão = (100, 776)
# Geracão 308: Melhor solucão = (100, 776)
# Geracão 309: Melhor solucão = (100, 776)
# Geracão 310: Melhor solucão = (100, 776)
# Geracão 311: Melhor solucão = (100, 776)
# Geracão 312: Melhor solucão = (100, 776)
# Geracão 313: Melhor solucão = (100, 776)
# Geracão 314: Melhor solucão = (100, 776)
# Geracão 315: Melhor solucão = (100, 776)
# Geracão 316: Melhor solucão = (100, 776)
# Geracão 317: Melhor solucão = (100, 776)
# Geracão 318: Melhor solucão = (100, 776)
# Geracão 319: Melhor solucão = (100, 776)
# Geracão 320: Melhor solucão = (100, 776)
# Geracão 321: Melhor solucão = (100, 776)
# Geracão 322: Melhor solucão = (100, 776)
# Geracão 323: Melhor solucão = (100, 776)
# Geracão 324: Melhor solucão = (100, 776)
# Geracão 325: Melhor solucão = (100, 776)
# Geracão 326: Melhor solucão = (100, 776)
# Geracão 327: Melhor solucão = (100, 776)
# Geracão 328: Melhor solucão = (100, 776)
# Geracão 329: Melhor solucão = (100, 776)
# Geracão 330: Melhor solucão = (100, 776)
# Geracão 331: Melhor solucão = (100, 776)
# Geracão 332: Melhor solucão = (100, 776)
# Geracão 333: Melhor solucão = (100, 776)
# Geracão 334: Melhor solucão = (100, 776)
# Geracão 335: Melhor solucão = (100, 776)
# Geracão 336: Melhor solucão = (100, 776)
# Geracão 337: Melhor solucão = (100, 776)
# Geracão 338: Melhor solucão = (100, 776)
# Geracão 339: Melhor solucão = (100, 776)
# Geracão 340: Melhor solucão = (100, 776)
# Geracão 341: Melhor solucão = (100, 776)
# Geracão 342: Melhor solucão = (100, 776)
# Geracão 343: Melhor solucão = (100, 776)
# Geracão 344: Melhor solucão = (100, 776)
# Geracão 345: Melhor solucão = (100, 776)
# Geracão 346: Melhor solucão = (100, 776)
# Geracão 347: Melhor solucão = (100, 776)
# Geracão 348: Melhor solucão = (100, 776)
# Geracão 349: Melhor solucão = (100, 776)
# Geracão 350: Melhor solucão = (100, 776)
# Geracão 351: Melhor solucão = (100, 776)
# Geracão 352: Melhor solucão = (100, 776)
# Geracão 353: Melhor solucão = (100, 776)
# Geracão 354: Melhor solucão = (100, 776)
# Geracão 355: Melhor solucão = (100, 776)
# Geracão 356: Melhor solucão = (100, 776)
# Geracão 357: Melhor solucão = (100, 776)
# Geracão 358: Melhor solucão = (100, 776)
# Geracão 359: Melhor solucão = (100, 776)
# Geracão 360: Melhor solucão = (100, 776)
# Geracão 361: Melhor solucão = (100, 776)
# Geracão 362: Melhor solucão = (100, 776)
# Geracão 363: Melhor solucão = (100, 776)
# Geracão 364: Melhor solucão = (100, 776)
# Geracão 365: Melhor solucão = (100, 776)
# Geracão 366: Melhor solucão = (100, 776)
# Geracão 367: Melhor solucão = (100, 776)
# Geracão 368: Melhor solucão = (100, 776)
# Geracão 369: Melhor solucão = (100, 776)
# Geracão 370: Melhor solucão = (100, 776)
# Geracão 371: Melhor solucão = (100, 776)
# Geracão 372: Melhor solucão = (100, 776)
# Geracão 373: Melhor solucão = (100, 776)
# Geracão 374: Melhor solucão = (100, 776)
# Geracão 375: Melhor solucão = (100, 776)
# Geracão 376: Melhor solucão = (100, 776)
# Geracão 377: Melhor solucão = (100, 776)
# Geracão 378: Melhor solucão = (100, 776)
# Geracão 379: Melhor solucão = (100, 776)
# Geracão 380: Melhor solucão = (100, 776)
# Geracão 381: Melhor solucão = (100, 776)
# Geracão 382: Melhor solucão = (100, 776)
# Geracão 383: Melhor solucão = (100, 776)
# Geracão 384: Melhor solucão = (100, 776)
# Geracão 385: Melhor solucão = (100, 776)
# Geracão 386: Melhor solucão = (100, 776)
# Geracão 387: Melhor solucão = (100, 776)
# Geracão 388: Melhor solucão = (100, 776)
# Geracão 389: Melhor solucão = (100, 776)
# Geracão 390: Melhor solucão = (100, 776)
# Geracão 391: Melhor solucão = (100, 776)
# Geracão 392: Melhor solucão = (100, 776)
# Geracão 393: Melhor solucão = (100, 776)
# Geracão 394: Melhor solucão = (100, 776)
# Geracão 395: Melhor solucão = (100, 776)
# Geracão 396: Melhor solucão = (100, 776)
# Geracão 397: Melhor solucão = (100, 776)
# Geracão 398: Melhor solucão = (100, 776)
# Geracão 399: Melhor solucão = (100, 776)
# Geracão 400: Melhor solucão = (100, 776)
# Geracão 401: Melhor solucão = (100, 776)
# Geracão 402: Melhor solucão = (100, 776)
# Geracão 403: Melhor solucão = (100, 776)
# Geracão 404: Melhor solucão = (100, 776)
# Geracão 405: Melhor solucão = (100, 776)
# Geracão 406: Melhor solucão = (100, 776)
# Geracão 407: Melhor solucão = (100, 776)
# Geracão 408: Melhor solucão = (100, 776)
# Geracão 409: Melhor solucão = (100, 776)
# Geracão 410: Melhor solucão = (100, 776)
# Geracão 411: Melhor solucão = (100, 776)
# Geracão 412: Melhor solucão = (100, 776)
# Geracão 413: Melhor solucão = (100, 776)
# Geracão 414: Melhor solucão = (100, 776)
# Geracão 415: Melhor solucão = (100, 776)
# Geracão 416: Melhor solucão = (100, 776)
# Geracão 417: Melhor solucão = (100, 776)
# Geracão 418: Melhor solucão = (100, 776)
# Geracão 419: Melhor solucão = (100, 776)
# Geracão 420: Melhor solucão = (100, 776)
# Geracão 421: Melhor solucão = (100, 776)
# Geracão 422: Melhor solucão = (100, 776)
# Geracão 423: Melhor solucão = (100, 776)
# Geracão 424: Melhor solucão = (100, 776)
# Geracão 425: Melhor solucão = (100, 776)
# Geracão 426: Melhor solucão = (100, 776)
# Geracão 427: Melhor solucão = (100, 776)
# Geracão 428: Melhor solucão = (100, 776)
# Geracão 429: Melhor solucão = (100, 776)
# Geracão 430: Melhor solucão = (100, 776)
# Geracão 431: Melhor solucão = (100, 776)
# Geracão 432: Melhor solucão = (100, 776)
# Geracão 433: Melhor solucão = (100, 776)
# Geracão 434: Melhor solucão = (100, 776)
# Geracão 435: Melhor solucão = (100, 776)
# Geracão 436: Melhor solucão = (100, 776)
# Geracão 437: Melhor solucão = (100, 776)
# Geracão 438: Melhor solucão = (100, 776)
# Geracão 439: Melhor solucão = (100, 776)
# Geracão 440: Melhor solucão = (100, 776)
# Geracão 441: Melhor solucão = (100, 776)
# Geracão 442: Melhor solucão = (100, 776)
# Geracão 443: Melhor solucão = (100, 776)
# Geracão 444: Melhor solucão = (100, 776)
# Geracão 445: Melhor solucão = (100, 776)
# Geracão 446: Melhor solucão = (100, 776)
# Geracão 447: Melhor solucão = (100, 776)
# Geracão 448: Melhor solucão = (100, 776)
# Geracão 449: Melhor solucão = (100, 776)
# Geracão 450: Melhor solucão = (100, 776)
# Geracão 451: Melhor solucão = (100, 776)
# Geracão 452: Melhor solucão = (100, 776)
# Geracão 453: Melhor solucão = (100, 776)
# Geracão 454: Melhor solucão = (100, 776)
# Geracão 455: Melhor solucão = (100, 776)
# Geracão 456: Melhor solucão = (100, 776)
# Geracão 457: Melhor solucão = (100, 776)
# Geracão 458: Melhor solucão = (100, 776)
# Geracão 459: Melhor solucão = (100, 776)
# Geracão 460: Melhor solucão = (100, 776)
# Geracão 461: Melhor solucão = (100, 776)
# Geracão 462: Melhor solucão = (100, 776)
# Geracão 463: Melhor solucão = (100, 776)
# Geracão 464: Melhor solucão = (100, 776)
# Geracão 465: Melhor solucão = (100, 776)
# Geracão 466: Melhor solucão = (100, 776)
# Geracão 467: Melhor solucão = (100, 776)
# Geracão 468: Melhor solucão = (100, 776)
# Geracão 469: Melhor solucão = (100, 776)
# Geracão 470: Melhor solucão = (100, 776)
# Geracão 471: Melhor solucão = (100, 776)
# Geracão 472: Melhor solucão = (100, 776)
# Geracão 473: Melhor solucão = (100, 776)
# Geracão 474: Melhor solucão = (100, 776)
# Geracão 475: Melhor solucão = (100, 776)
# Geracão 476: Melhor solucão = (100, 776)
# Geracão 477: Melhor solucão = (100, 776)
# Geracão 478: Melhor solucão = (100, 776)
# Geracão 479: Melhor solucão = (100, 776)
# Geracão 480: Melhor solucão = (100, 776)
# Geracão 481: Melhor solucão = (100, 776)
# Geracão 482: Melhor solucão = (100, 776)
# Geracão 483: Melhor solucão = (100, 776)
# Geracão 484: Melhor solucão = (100, 776)
# Geracão 485: Melhor solucão = (100, 776)
# Geracão 486: Melhor solucão = (100, 776)
# Geracão 487: Melhor solucão = (100, 776)
# Geracão 488: Melhor solucão = (100, 776)
# Geracão 489: Melhor solucão = (100, 776)
# Geracão 490: Melhor solucão = (100, 776)
# Geracão 491: Melhor solucão = (100, 776)
# Geracão 492: Melhor solucão = (100, 776)
# Geracão 493: Melhor solucão = (100, 776)
# Geracão 494: Melhor solucão = (100, 776)
# Geracão 495: Melhor solucão = (100, 776)
# Geracão 496: Melhor solucão = (100, 776)
# Geracão 497: Melhor solucão = (100, 776)
# Geracão 498: Melhor solucão = (100, 776)
# Geracão 499: Melhor solucão = (100, 776)
